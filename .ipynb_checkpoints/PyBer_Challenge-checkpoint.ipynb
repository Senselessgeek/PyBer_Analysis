# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to check these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Challenge Deliverable 1. Generate a Ride-Sharing DataFrame by City Type

# %%
#  1. Get the total rides for each city type
total_rides = pyber_data_df.groupby(["city"]).count()["ride_id"]
total_rides
# Out:
# city
# Amandaburgh         18
# Barajasview         22
# Barronchester       16
# Bethanyland         18
# Bradshawfurt        10
#                     ..
# West Robert         31
# West Samuelburgh    25
# Williamsonville     14
# Williamsstad        23
# Williamsview        20
# Name: ride_id, Length: 120, dtype: int64

# %%
# 2. Get the total drivers for each city type
total_drivers = pyber_data_df.groupby(["city"]).sum()["driver_count"]
total_drivers
# Out:
# C:\Users\andmarst\AppData\Local\Temp\ipykernel_27864\4028588364.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_drivers = pyber_data_df.groupby(["city"]).sum()["driver_count"]
# city
# Amandaburgh          216
# Barajasview          572
# Barronchester        176
# Bethanyland          396
# Bradshawfurt          70
#                     ...
# West Robert         1209
# West Samuelburgh    1825
# Williamsonville       28
# Williamsstad        1357
# Williamsview         920
# Name: driver_count, Length: 120, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
total_fares = pyber_data_df.groupby(["city"]).sum()["fare"]
total_fares
# Out:
# C:\Users\andmarst\AppData\Local\Temp\ipykernel_27864\2807877828.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   total_fares = pyber_data_df.groupby(["city"]).sum()["fare"]
# city
# Amandaburgh         443.55
# Barajasview         557.31
# Barronchester       582.76
# Bethanyland         593.21
# Bradshawfurt        400.64
#                      ...
# West Robert         778.84
# West Samuelburgh    544.19
# Williamsonville     446.25
# Williamsstad        560.33
# Williamsview        531.98
# Name: fare, Length: 120, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
avg_fares = pyber_data_df.groupby(["city"]).mean()["fare"]
avg_fares
# Out:
# C:\Users\andmarst\AppData\Local\Temp\ipykernel_27864\3810042059.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_fares = pyber_data_df.groupby(["city"]).mean()["fare"]
# city
# Amandaburgh         24.641667
# Barajasview         25.332273
# Barronchester       36.422500
# Bethanyland         32.956111
# Bradshawfurt        40.064000
#                       ...
# West Robert         25.123871
# West Samuelburgh    21.767600
# Williamsonville     31.875000
# Williamsstad        24.362174
# Williamsview        26.599000
# Name: fare, Length: 120, dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_per_driver = total_fares.divide(total_drivers)
avg_per_driver
# Out:
# city
# Amandaburgh          2.053472
# Barajasview          0.974318
# Barronchester        3.311136
# Bethanyland          1.498005
# Bradshawfurt         5.723429
#                       ...
# West Robert          0.644202
# West Samuelburgh     0.298186
# Williamsonville     15.937500
# Williamsstad         0.412918
# Williamsview         0.578239
# Length: 120, dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary = pd.DataFrame(columns = ['Total Rides', 'Total Drivers', 'Total Fares', 'Average Fare per Ride', 'Average Fare per Driver'])
pyber_summary['Total Rides'] =  total_rides
pyber_summary['Total Drivers'] =  total_drivers
pyber_summary['Total Fares'] =  total_fares
pyber_summary['Average Fare per Ride'] =  avg_fares
pyber_summary['Average Fare per Driver'] =  avg_per_driver

pyber_summary
# Out:
#                   Total Rides  Total Drivers  Total Fares  \
# city
# Amandaburgh                18            216       443.55
# Barajasview                22            572       557.31
# Barronchester              16            176       582.76
# Bethanyland                18            396       593.21
# Bradshawfurt               10             70       400.64
# ...                       ...            ...          ...
# West Robert                31           1209       778.84
# West Samuelburgh           25           1825       544.19
# Williamsonville            14             28       446.25
# Williamsstad               23           1357       560.33
# Williamsview               20            920       531.98
#
#                   Average Fare per Ride  Average Fare per Driver
# city
# Amandaburgh                   24.641667                 2.053472
# Barajasview                   25.332273                 0.974318
# Barronchester                 36.422500                 3.311136
# Bethanyland                   32.956111                 1.498005
# Bradshawfurt                  40.064000                 5.723429
# ...                                 ...                      ...
# West Robert                   25.123871                 0.644202
# West Samuelburgh              21.767600                 0.298186
# Williamsonville               31.875000                15.937500
# Williamsstad                  24.362174                 0.412918
# Williamsview                  26.599000                 0.578239
#
# [120 rows x 5 columns]

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary.index.name = None

pyber_summary
# Out:
#                   Total Rides  Total Drivers  Total Fares  \
# Amandaburgh                18            216       443.55
# Barajasview                22            572       557.31
# Barronchester              16            176       582.76
# Bethanyland                18            396       593.21
# Bradshawfurt               10             70       400.64
# ...                       ...            ...          ...
# West Robert                31           1209       778.84
# West Samuelburgh           25           1825       544.19
# Williamsonville            14             28       446.25
# Williamsstad               23           1357       560.33
# Williamsview               20            920       531.98
#
#                   Average Fare per Ride  Average Fare per Driver
# Amandaburgh                   24.641667                 2.053472
# Barajasview                   25.332273                 0.974318
# Barronchester                 36.422500                 3.311136
# Bethanyland                   32.956111                 1.498005
# Bradshawfurt                  40.064000                 5.723429
# ...                                 ...                      ...
# West Robert                   25.123871                 0.644202
# West Samuelburgh              21.767600                 0.298186
# Williamsonville               31.875000                15.937500
# Williamsstad                  24.362174                 0.412918
# Williamsview                  26.599000                 0.578239
#
# [120 rows x 5 columns]

# %%
#  8. Format the columns.
pyber_summary.style.format({"Total Rides": '{:,}',"Total Drivers": '{:,}',"Total Fares": '${:.2f}',"Average Fare per Ride": '${:.2f}',"Average Fare per Driver": '${:.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_3b762">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b762_level0_col0" class="col_heading level0 col0" >Total Rides</th>
#       <th id="T_3b762_level0_col1" class="col_heading level0 col1" >Total Drivers</th>
#       <th id="T_3b762_level0_col2" class="col_heading level0 col2" >Total Fares</th>
#       <th id="T_3b762_level0_col3" class="col_heading level0 col3" >Average Fare per Ride</th>
#       <th id="T_3b762_level0_col4" class="col_heading level0 col4" >Average Fare per Driver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b762_level0_row0" class="row_heading level0 row0" >Amandaburgh</th>
#       <td id="T_3b762_row0_col0" class="data row0 col0" >18</td>
#       <td id="T_3b762_row0_col1" class="data row0 col1" >216</td>
#       <td id="T_3b762_row0_col2" class="data row0 col2" >$443.55</td>
#       <td id="T_3b762_row0_col3" class="data row0 col3" >$24.64</td>
#       <td id="T_3b762_row0_col4" class="data row0 col4" >$2.05</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row1" class="row_heading level0 row1" >Barajasview</th>
#       <td id="T_3b762_row1_col0" class="data row1 col0" >22</td>
#       <td id="T_3b762_row1_col1" class="data row1 col1" >572</td>
#       <td id="T_3b762_row1_col2" class="data row1 col2" >$557.31</td>
#       <td id="T_3b762_row1_col3" class="data row1 col3" >$25.33</td>
#       <td id="T_3b762_row1_col4" class="data row1 col4" >$0.97</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row2" class="row_heading level0 row2" >Barronchester</th>
#       <td id="T_3b762_row2_col0" class="data row2 col0" >16</td>
#       <td id="T_3b762_row2_col1" class="data row2 col1" >176</td>
#       <td id="T_3b762_row2_col2" class="data row2 col2" >$582.76</td>
#       <td id="T_3b762_row2_col3" class="data row2 col3" >$36.42</td>
#       <td id="T_3b762_row2_col4" class="data row2 col4" >$3.31</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row3" class="row_heading level0 row3" >Bethanyland</th>
#       <td id="T_3b762_row3_col0" class="data row3 col0" >18</td>
#       <td id="T_3b762_row3_col1" class="data row3 col1" >396</td>
#       <td id="T_3b762_row3_col2" class="data row3 col2" >$593.21</td>
#       <td id="T_3b762_row3_col3" class="data row3 col3" >$32.96</td>
#       <td id="T_3b762_row3_col4" class="data row3 col4" >$1.50</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row4" class="row_heading level0 row4" >Bradshawfurt</th>
#       <td id="T_3b762_row4_col0" class="data row4 col0" >10</td>
#       <td id="T_3b762_row4_col1" class="data row4 col1" >70</td>
#       <td id="T_3b762_row4_col2" class="data row4 col2" >$400.64</td>
#       <td id="T_3b762_row4_col3" class="data row4 col3" >$40.06</td>
#       <td id="T_3b762_row4_col4" class="data row4 col4" >$5.72</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row5" class="row_heading level0 row5" >Brandonfort</th>
#       <td id="T_3b762_row5_col0" class="data row5 col0" >19</td>
#       <td id="T_3b762_row5_col1" class="data row5 col1" >190</td>
#       <td id="T_3b762_row5_col2" class="data row5 col2" >$673.31</td>
#       <td id="T_3b762_row5_col3" class="data row5 col3" >$35.44</td>
#       <td id="T_3b762_row5_col4" class="data row5 col4" >$3.54</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row6" class="row_heading level0 row6" >Carriemouth</th>
#       <td id="T_3b762_row6_col0" class="data row6 col0" >27</td>
#       <td id="T_3b762_row6_col1" class="data row6 col1" >1,404</td>
#       <td id="T_3b762_row6_col2" class="data row6 col2" >$764.49</td>
#       <td id="T_3b762_row6_col3" class="data row6 col3" >$28.31</td>
#       <td id="T_3b762_row6_col4" class="data row6 col4" >$0.54</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row7" class="row_heading level0 row7" >Christopherfurt</th>
#       <td id="T_3b762_row7_col0" class="data row7 col0" >27</td>
#       <td id="T_3b762_row7_col1" class="data row7 col1" >1,107</td>
#       <td id="T_3b762_row7_col2" class="data row7 col2" >$661.55</td>
#       <td id="T_3b762_row7_col3" class="data row7 col3" >$24.50</td>
#       <td id="T_3b762_row7_col4" class="data row7 col4" >$0.60</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row8" class="row_heading level0 row8" >Colemanland</th>
#       <td id="T_3b762_row8_col0" class="data row8 col0" >22</td>
#       <td id="T_3b762_row8_col1" class="data row8 col1" >506</td>
#       <td id="T_3b762_row8_col2" class="data row8 col2" >$679.68</td>
#       <td id="T_3b762_row8_col3" class="data row8 col3" >$30.89</td>
#       <td id="T_3b762_row8_col4" class="data row8 col4" >$1.34</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row9" class="row_heading level0 row9" >Davidfurt</th>
#       <td id="T_3b762_row9_col0" class="data row9 col0" >17</td>
#       <td id="T_3b762_row9_col1" class="data row9 col1" >391</td>
#       <td id="T_3b762_row9_col2" class="data row9 col2" >$543.93</td>
#       <td id="T_3b762_row9_col3" class="data row9 col3" >$32.00</td>
#       <td id="T_3b762_row9_col4" class="data row9 col4" >$1.39</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row10" class="row_heading level0 row10" >Deanville</th>
#       <td id="T_3b762_row10_col0" class="data row10 col0" >19</td>
#       <td id="T_3b762_row10_col1" class="data row10 col1" >931</td>
#       <td id="T_3b762_row10_col2" class="data row10 col2" >$491.01</td>
#       <td id="T_3b762_row10_col3" class="data row10 col3" >$25.84</td>
#       <td id="T_3b762_row10_col4" class="data row10 col4" >$0.53</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row11" class="row_heading level0 row11" >East Aaronbury</th>
#       <td id="T_3b762_row11_col0" class="data row11 col0" >9</td>
#       <td id="T_3b762_row11_col1" class="data row11 col1" >63</td>
#       <td id="T_3b762_row11_col2" class="data row11 col2" >$230.95</td>
#       <td id="T_3b762_row11_col3" class="data row11 col3" >$25.66</td>
#       <td id="T_3b762_row11_col4" class="data row11 col4" >$3.67</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row12" class="row_heading level0 row12" >East Danielview</th>
#       <td id="T_3b762_row12_col0" class="data row12 col0" >17</td>
#       <td id="T_3b762_row12_col1" class="data row12 col1" >374</td>
#       <td id="T_3b762_row12_col2" class="data row12 col2" >$536.53</td>
#       <td id="T_3b762_row12_col3" class="data row12 col3" >$31.56</td>
#       <td id="T_3b762_row12_col4" class="data row12 col4" >$1.43</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row13" class="row_heading level0 row13" >East Kaylahaven</th>
#       <td id="T_3b762_row13_col0" class="data row13 col0" >29</td>
#       <td id="T_3b762_row13_col1" class="data row13 col1" >1,885</td>
#       <td id="T_3b762_row13_col2" class="data row13 col2" >$688.98</td>
#       <td id="T_3b762_row13_col3" class="data row13 col3" >$23.76</td>
#       <td id="T_3b762_row13_col4" class="data row13 col4" >$0.37</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row14" class="row_heading level0 row14" >East Kentstad</th>
#       <td id="T_3b762_row14_col0" class="data row14 col0" >13</td>
#       <td id="T_3b762_row14_col1" class="data row14 col1" >260</td>
#       <td id="T_3b762_row14_col2" class="data row14 col2" >$387.70</td>
#       <td id="T_3b762_row14_col3" class="data row14 col3" >$29.82</td>
#       <td id="T_3b762_row14_col4" class="data row14 col4" >$1.49</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row15" class="row_heading level0 row15" >East Marymouth</th>
#       <td id="T_3b762_row15_col0" class="data row15 col0" >27</td>
#       <td id="T_3b762_row15_col1" class="data row15 col1" >135</td>
#       <td id="T_3b762_row15_col2" class="data row15 col2" >$832.55</td>
#       <td id="T_3b762_row15_col3" class="data row15 col3" >$30.84</td>
#       <td id="T_3b762_row15_col4" class="data row15 col4" >$6.17</td>
#     </tr>
#     <tr>
#       <th id="T_3b762_level0_row16" class="row_heading level0 row16" >Erikaland</th>
#       <td id="T_3b762_row16_col0" class="data row16 col0" >12</td>
#       <td id="T_3b762_row16_col1" class="data row16 col1" >444</td>
#       <t

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# Print the merged DataFrame for reference.
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# 4               46  Urban
# ...            ...    ...
# 2370             6  Rural
# 2371             2  Rural
# 2372             1  Rural
# 2373             4  Rural
# 2374             1  Rural
#
# [2375 rows x 6 columns]

# %%
# 1. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
cdfares = pyber_data_df.groupby(["city", "date"]).sum()["fare"]
cdfares
# Out:
# C:\Users\andmarst\AppData\Local\Temp\ipykernel_27864\1464768539.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   cdfares = pyber_data_df.groupby(["city", "date"]).sum()["fare"]
# city          date
# Amandaburgh   2019-01-02 09:57:04    33.06
#               2019-01-11 02:22:07    29.24
#               2019-01-13 16:04:10    23.35
#               2019-01-21 04:12:54     9.26
#               2019-01-29 23:28:12    41.06
#                                      ...
# Williamsview  2019-04-15 16:09:08    44.74
#               2019-04-16 08:23:02    20.38
#               2019-04-18 02:07:15    39.79
#               2019-04-26 00:30:10    20.89
#               2019-05-04 14:56:45    32.80
# Name: fare, Length: 2375, dtype: float64

# %%
# 2. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
cdfares = cdfares.reset_index()
cdfares
# Out:
#               city                 date   fare
# 0      Amandaburgh  2019-01-02 09:57:04  33.06
# 1      Amandaburgh  2019-01-11 02:22:07  29.24
# 2      Amandaburgh  2019-01-13 16:04:10  23.35
# 3      Amandaburgh  2019-01-21 04:12:54   9.26
# 4      Amandaburgh  2019-01-29 23:28:12  41.06
# ...            ...                  ...    ...
# 2370  Williamsview  2019-04-15 16:09:08  44.74
# 2371  Williamsview  2019-04-16 08:23:02  20.38
# 2372  Williamsview  2019-04-18 02:07:15  39.79
# 2373  Williamsview  2019-04-26 00:30:10  20.89
# 2374  Williamsview  2019-05-04 14:56:45  32.80
#
# [2375 rows x 3 columns]

# %%
# 3. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
fares_date_pivot = cdfares.pivot(index=["date"], columns=["city"],values="fare")
fares_date_pivot
# Out:
# city                 Amandaburgh  Barajasview  Barronchester  Bethanyland  \
# date
# 2019-01-01 00:08:16          NaN          NaN            NaN          NaN
# 2019-01-01 00:46:46          NaN          NaN            NaN          NaN
# 2019-01-01 02:07:24          NaN          NaN            NaN          NaN
# 2019-01-01 03:46:50          NaN          NaN            NaN          NaN
# 2019-01-01 05:23:21          NaN          NaN            NaN          NaN
# ...                          ...          ...            ...          ...
# 2019-05-08 04:20:00          NaN          NaN            NaN          NaN
# 2019-05-08 04:39:49          NaN          NaN            NaN          NaN
# 2019-05-08 07:29:01          NaN          NaN            NaN          NaN
# 2019-05-08 11:38:35          NaN          NaN            NaN          NaN
# 2019-05-08 13:10:18          NaN          NaN            NaN          NaN
#
# city                 Bradshawfurt  Brandonfort  Carriemouth  Christopherfurt  \
# date
# 2019-01-01 00:08:16           NaN          NaN          NaN              NaN
# 2019-01-01 00:46:46           NaN          NaN          NaN              NaN
# 2019-01-01 02:07:24           NaN          NaN          NaN              NaN
# 2019-01-01 03:46:50           NaN          NaN          NaN              NaN
# 2019-01-01 05:23:21           NaN          NaN          NaN              NaN
# ...                           ...          ...          ...              ...
# 2019-05-08 04:20:00           NaN          NaN        21.99              NaN
# 2019-05-08 04:39:49           NaN          NaN          NaN              NaN
# 2019-05-08 07:29:01           NaN          NaN          NaN              NaN
# 2019-05-08 11:38:35           NaN          NaN          NaN              NaN
# 2019-05-08 13:10:18           NaN          NaN          NaN              NaN
#
# city                 Colemanland  Davidfurt  ...  West Heather  West Heidi  \
# date                                         ...
# 2019-01-01 00:08:16          NaN        NaN  ...           NaN         NaN
# 2019-01-01 00:46:46        47.74        NaN  ...           NaN         NaN
# 2019-01-01 02:07:24          NaN        NaN  ...           NaN         NaN
# 2019-01-01 03:46:50          NaN        NaN  ...           NaN         NaN
# 2019-01-01 05:23:21          NaN        NaN  ...           NaN       10.75
# ...                          ...        ...  ...           ...         ...
# 2019-05-08 04:20:00          NaN        NaN  ...           NaN         NaN
# 2019-05-08 04:39:49          NaN        NaN  ...           NaN         NaN
# 2019-05-08 07:29:01          NaN        NaN  ...           NaN         NaN
# 2019-05-08 11:38:35          NaN        NaN  ...           NaN         NaN
# 2019-05-08 13:10:18          NaN        NaN  ...           NaN         NaN
#
# city                 West Josephberg  West Kimmouth  West Patrickchester  \
# date
# 2019-01-01 00:08:16              NaN            NaN                  NaN
# 2019-01-01 00:46:46              NaN            NaN                  NaN
# 2019-01-01 02:07:24              NaN            NaN                  NaN
# 2019-01-01 03:46:50              NaN            NaN                  NaN
# 2019-01-01 05:23:21              NaN            NaN                  NaN
# ...                              ...            ...                  ...
# 2019-05-08 04:20:00              NaN            NaN                  NaN
# 2019-05-08 04:39:49              NaN            NaN                  NaN
# 2019-05-08 07:29:01              NaN            NaN                  NaN
# 2019-05-08 11:38:35              NaN            NaN                  NaN
# 2019-05-08 13:10:18              NaN            NaN                  NaN
#
# city                 West Robert  West Samuelburgh  Williamsonville  \
# date
# 2019-01-01 00:08:16          NaN               NaN              NaN
# 2019-01-01 00:46:46          NaN               NaN              NaN
# 2019-01-01 02:07:24          NaN               NaN              NaN
# 2019-01-01 03:46:50          NaN               NaN              NaN
# 2019-01-01 05:23:21          NaN               NaN              NaN
# ...                          ...               ...              ...
# 2019-05-08 04:20:00          NaN               NaN              NaN
# 2019-05-08 04:39:49          NaN               NaN              NaN
# 2019-05-08 07:29:01          NaN               NaN              NaN
# 2019-05-08 11:38:35          NaN               NaN              NaN
# 2019-05-08 13:10:18          NaN               NaN              NaN
#
# city                 Williamsstad  Williamsview
# date
# 2019-01-01 00:08:16           NaN           NaN
# 2019-01-01 00:46:46           NaN           NaN
# 2019-01-01 02:07:24           NaN           NaN
# 2019-01-01 03:46:50           NaN           NaN
# 2019-01-01 05:23:21           NaN           NaN
# ...                           ...           ...
# 2019-05-08 04:20:00           NaN           NaN
# 2019-05-08 04:39:49           NaN           NaN
# 2019-05-08 07:29:01           NaN           NaN
# 2019-05-08 11:38:35           NaN           NaN
# 2019-05-08 13:10:18           NaN           NaN
#
# [2375 rows x 120 columns]

# %%
# 4. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-28'.

jan_apr = fares_date_pivot.loc['2019-01-01':'2019-04-28']

# %%
# 5. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
jan_apr.index = pd.to_datetime(jan_apr.index)

# %%
# 6. Check that the datatype for the index is datetime using df.info()
jan_apr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2177 entries, 2019-01-01 00:08:16 to 2019-04-27 23:52:44
# Columns: 120 entries, Amandaburgh to Williamsview
# dtypes: float64(120)
# memory usage: 2.0 MB

# %%
# 7. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
jan_apr = jan_apr.resample('W').sum()

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')


jan_apr.plot(figsize=(40,10))
plt.title("Total Fare by City Type")
plt.ylabel("Fare($USD)")
plt.xlabel("Weeks", rotation='horizontal')
plt.legend(loc="upper center", ncols=15)
plt.draw()
plt.xticks(rotation = 45)

plt.show()
